# %%
import xarray as xr
import zarr

# %%
zarr_file_path = 'zarr_store/20220101.zarr'

# %%
ds = xr.open_dataset(zarr_file_path, decode_timedelta=False)

# %%
ds
# Out:
# <xarray.Dataset> Size: 2GB
# Dimensions:    (step: 161, latitude: 281, longitude: 540)
# Coordinates:
#   * latitude   (latitude) float64 2kB -70.0 -69.75 -69.5 ... -0.5 -0.25 0.0
#   * longitude  (longitude) float64 4kB 0.0 0.25 0.5 0.75 ... 134.3 134.5 134.8
#   * step       (step) float64 1kB 0.0 1.0 2.0 3.0 ... 231.0 234.0 237.0 240.0
#     time       datetime64[ns] 8B ...
# Data variables: (12/19)
#     dirpw      (step, latitude, longitude) float32 98MB ...
#     mpts_0     (step, latitude, longitude) float32 98MB ...
#     mpts_1     (step, latitude, longitude) float32 98MB ...
#     mpts_2     (step, latitude, longitude) float32 98MB ...
#     mpww       (step, latitude, longitude) float32 98MB ...
#     perpw      (step, latitude, longitude) float32 98MB ...
#     ...         ...
#     swh        (step, latitude, longitude) float32 98MB ...
#     u          (step, latitude, longitude) float32 98MB ...
#     v          (step, latitude, longitude) float32 98MB ...
# ...
