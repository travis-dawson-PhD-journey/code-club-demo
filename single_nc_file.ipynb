# %%
import xarray as xr

# %%
nc_file_path = "gfs_sample/gfs.20220101/00/wave/gridded/gfswave.t00z.global.0p25.f000.grib2"

# %%
ds = xr.load_dataset(nc_file_path,
                     engine='cfgrib',
                     decode_timedelta=False)

# %%
ds
# Out:
# <xarray.Dataset> Size: 79MB
# Dimensions:              (latitude: 721, longitude: 1440, orderedSequenceData: 3)
# Coordinates:
#     time                 datetime64[ns] 8B 2022-01-01
#     step                 float64 8B 0.0
#     surface              float64 8B 1.0
#   * latitude             (latitude) float64 6kB 90.0 89.75 89.5 ... -89.75 -90.0
#   * longitude            (longitude) float64 12kB 0.0 0.25 0.5 ... 359.5 359.8
#     valid_time           datetime64[ns] 8B 2022-01-01
#   * orderedSequenceData  (orderedSequenceData) float64 24B 1.0 2.0 3.0
# Data variables: (12/13)
#     ws                   (latitude, longitude) float32 4MB nan nan ... nan nan
#     wdir                 (latitude, longitude) float32 4MB nan nan ... nan nan
#     u                    (latitude, longitude) float32 4MB nan nan ... nan nan
#     v                    (latitude, longitude) float32 4MB nan nan ... nan nan
#     swh                  (latitude, longitude) float32 4MB nan nan ... nan nan
# ...
