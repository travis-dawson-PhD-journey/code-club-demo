# %% [markdown]
# Please use the virual environment as the selected kernel.

# %%
import xarray as xr
import zarr

# %%
# SPecify the partial zarr file path
partial_zarr_file_path = './zarr_partial/20220101.zarr'

# %% [markdown]
# Execute a metadata consolidation, where it will review the available metadata in the partial file, to reflect the accurate file

# %%
zarr.consolidate_metadata(partial_zarr_file_path)
# Out:
# <Group file://zarr_partial/20220101.zarr>

# %%
# Open the dataset
ds = xr.open_dataset(partial_zarr_file_path, decode_timedelta=False)

# %%
# Display the dataset
ds
# Out:
# <xarray.Dataset> Size: 293MB
# Dimensions:    (step: 161, latitude: 281, longitude: 540)
# Coordinates:
#   * latitude   (latitude) float64 2kB -70.0 -69.75 -69.5 ... -0.5 -0.25 0.0
#   * longitude  (longitude) float64 4kB 0.0 0.25 0.5 0.75 ... 134.3 134.5 134.8
#     time       datetime64[ns] 8B ...
# Dimensions without coordinates: step
# Data variables:
#     swh        (step, latitude, longitude) float32 98MB ...
#     u          (step, latitude, longitude) float32 98MB ...
#     v          (step, latitude, longitude) float32 98MB ...
# Attributes:
#     GRIB_edition:            2
#     GRIB_centre:             kwbc
#     GRIB_centreDescription:  US National Weather Service - NCEP
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             US National Weather Service - NCEP
#     history:                 2025-09-01T15:42 GRIB to CDM+CF via cfgrib-0.9.1...
